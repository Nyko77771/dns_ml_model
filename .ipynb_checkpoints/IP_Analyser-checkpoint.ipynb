# %%
# ML Model for IP Analyses
# Data Collection

# Importing Libraries
# Importing ML building libries and tools from Python
import sklearn as sk
import pandas as pd
import numpy as nm

# Importing tarfile modele for opening DGArchive tar file
import tarfile
# Importing os module to writing/reading files to the os
import os


# Models / Algoriths Examined
# 1. Logistic Regression
# 2. K-Nearest Neighbour
# 3. Random Forest

# Importing Data
